# %%
import pandas as pd
movies = pd.read_csv('/home/mike/Documents/Coding/Data/movies_data/movies.csv')

display(movies.head())
display(movies.tail())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#       movieId                                      title  \
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                genres
# ...

# %%
display(movies.describe())
# Out:
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %%
ratings1 = pd.read_csv('/home/mike/Documents/Coding/Data/movies_data/ratings1.csv')

display(ratings1.head())
display(ratings1.describe())
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0
#              userId        movieId        rating
# count  40001.000000   40001.000000  40001.000000
# mean     134.711282   18898.619035      3.575223
# std       79.664674   35885.863627      1.022768
# min        1.000000       1.000000      0.500000
# 25%       66.000000    1079.000000      3.000000
# 50%      132.000000    2746.000000      4.000000
# 75%      208.000000    7153.000000      4.000000
# max      274.000000  193587.000000      5.000000

# %%
ratings2 = pd.read_csv('/home/mike/Documents/Coding/Data/movies_data/ratings2.csv')

display(ratings2.head())
display(ratings2.describe())
# Out:
#    userId  movieId  rating
# 0     274     5621     2.0
# 1     274     5630     3.0
# 2     274     5667     3.5
# 3     274     5679     3.5
# 4     274     5690     3.0
#              userId        movieId        rating
# count  60836.000000   60836.000000  60836.000000
# mean     451.987096   19787.945296      3.453095
# std      105.695306   35291.305531      1.052532
# min      274.000000       1.000000      0.500000
# 25%      366.000000    1225.000000      3.000000
# 50%      448.000000    3174.000000      3.500000
# 75%      555.000000    8622.000000      4.000000
# max      610.000000  193609.000000      5.000000

# %%
dates = pd.read_csv('/home/mike/Documents/Coding/Data/movies_data/dates.csv')

dates['date'] = pd.to_datetime(dates['date'])

print(dates['date'].dt.year.mode()[0])
# Out:
# 2000

# %%
ratings = pd.concat([ratings1, ratings2], ignore_index=True)
display(ratings)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
ratings_dates = pd.concat([ratings, dates], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                date  movieId_right  \
# 0            1        1     4.0 2000-07-30 18:45:03            1.0
# 1            1        3     4.0 2000-07-30 18:20:47            2.0
# 2            1        6     4.0 2000-07-30 18:37:04            3.0
# 3            1       47     5.0 2000-07-30 19:03:35            4.0
# 4            1       50     5.0 2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                 ...            ...
# 100831     610   166534     4.0 2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.tail())
# Out:
#         userId  movieId  rating                date  \
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15
#
#                                  title                       genres
# 100831                    Split (2017)        Drama|Horror|Thriller
# 100832   John Wick: Chapter Two (2017)        Action|Crime|Thriller
# 100833                  Get Out (2017)                       Horror
# 100834                    Logan (2017)                Action|Sci-Fi
# 100835  The Fate of the Furious (2017)  Action|Crime|Drama|Thriller

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.tail())
# Out:
#         userId  movieId  rating                date  \
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15
#
#                                  title                       genres
# 100831                    Split (2017)        Drama|Horror|Thriller
# 100832   John Wick: Chapter Two (2017)        Action|Crime|Thriller
# 100833                  Get Out (2017)                       Horror
# 100834                    Logan (2017)                Action|Sci-Fi
# 100835  The Fate of the Furious (2017)  Action|Crime|Drama|Thriller

# %%
ratings_movies = pd.read_csv('/home/mike/Documents/Coding/Data/movies_data/ratings_movies.csv')
display(ratings_movies.head())
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
joined['year_release'] = joined['title'].apply(get_year_release)
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   userId        100836 non-null  int64
#  1   movieId       100836 non-null  int64
#  2   rating        100836 non-null  float64
#  3   date          100836 non-null  datetime64[ns]
#  4   title         100836 non-null  object
#  5   genres        100836 non-null  object
#  6   year_release  100818 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 5.4+ MB

# %%
display(joined.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres  year_release
# 0  Adventure|Animation|Children|Comedy|Fantasy        1995.0
# 1                               Comedy|Romance        1995.0
# 2                        Action|Crime|Thriller        1995.0
# 3                             Mystery|Thriller        1995.0
# 4                       Crime|Mystery|Thriller        1995.0

# %%
mask = joined['year_release'] == 1999
joined[mask].groupby('title')['rating'].mean().sort_values()
# Out:
# title
# Bloodsport: The Dark Kumite (1999)            0.5
# Simon Sez (1999)                              1.0
# Chill Factor (1999)                           1.0
# Source, The (1999)                            1.0
# Trippin' (1999)                               1.0
#                                              ...
# Trailer Park Boys (1999)                      5.0
# Larry David: Curb Your Enthusiasm (1999)      5.0
# Sun Alley (Sonnenallee) (1999)                5.0
# George Carlin: You Are All Diseased (1999)    5.0
# Five Senses, The (1999)                       5.0
# Name: rating, Length: 261, dtype: float64

# %%
mask = joined['year_release'] == 2010
joined[mask].groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %%
joined.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
joined.groupby('userId')['rating'].agg(
    ['count', 'mean']
).sort_values(['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
mask = joined['year_release'] == 2018
grouped = joined[mask].groupby('genres')['rating'].agg(
    ['mean', 'count']
)
grouped[grouped['count']>10].sort_values(
    by=['mean', 'count'],
    ascending=[False, False]
)
# Out:
#                              mean  count
# genres
# Action|Adventure|Sci-Fi  3.928571     14
# Action|Comedy|Sci-Fi     3.875000     12

# %%
joined['date'] = pd.to_datetime(joined['date'])
joined['year_rating'] = joined['date'].dt.year
pivot = joined.pivot_table(
    index='year_rating',
    columns='genres',
    values='rating',
    aggfunc='mean'
)
display(pivot)
# Out:
# genres       (no genres listed)    Action  Action|Adventure  \
# year_rating
# 1996                        NaN  2.730769          3.454545
# 1997                        NaN  3.538462          4.150000
# 1998                        NaN       NaN          4.200000
# 1999                        NaN       NaN          4.000000
# 2000                        NaN  2.588235          3.738462
# 2001                        NaN  3.000000          3.500000
# 2002                        NaN  2.750000          4.304348
# 2003                        NaN  3.833333          3.277778
# 2004                        NaN  2.700000          4.136364
# 2005                        NaN  3.357143          3.413043
# 2006                        NaN  2.166667          4.090909
# 2007                        NaN  2.583333          3.666667
# 2008                        NaN  3.000000          3.656250
# 2009                        NaN       NaN          3.714286
# ...

# %%
orders_df = pd.read_csv('/home/mike/Documents/Coding/Data/orders_and_products/orders.csv', sep=';')
display(orders_df.head())
# Out:
#          Дата создания  Order ID  ID Покупателя                    Статус  \
# 0  09.11.2019 21:55:51         9             10  Принят, ожидается оплата
# 1  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 2  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 3  09.11.2019 12:50:07         7              8  Принят, ожидается оплата
# 4  09.11.2019 12:00:00         6              1  Принят, ожидается оплата
#
#   Оплачен Отменен Отгружен  ID товара  Количество
# 0     Нет     Нет      Нет        103           5
# 1     Нет     Нет      Нет         86         100
# 2     Нет     Нет      Нет        104          10
# 3     Нет     Нет      Нет        104           7
# 4     Нет     Нет      Нет        104           5

# %%
product_df = pd.read_csv('/home/mike/Documents/Coding/Data/orders_and_products/products.csv', sep=';')
display(orders_df.head())
# Out:
#          Дата создания  Order ID  ID Покупателя                    Статус  \
# 0  09.11.2019 21:55:51         9             10  Принят, ожидается оплата
# 1  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 2  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 3  09.11.2019 12:50:07         7              8  Принят, ожидается оплата
# 4  09.11.2019 12:00:00         6              1  Принят, ожидается оплата
#
#   Оплачен Отменен Отгружен  ID товара  Количество
# 0     Нет     Нет      Нет        103           5
# 1     Нет     Нет      Нет         86         100
# 2     Нет     Нет      Нет        104          10
# 3     Нет     Нет      Нет        104           7
# 4     Нет     Нет      Нет        104           5

# %%
orders_products = orders_df.merge(
    product_df, 
    left_on='ID товара',
    right_on='Product_ID',
    how='left')
orders_products.tail(1)['Order ID']
# Out:
# 17    0
# Name: Order ID, dtype: int64

# %%
orders_products[orders_products['Отменен'] == 'Да']['Name']
# Out:
# 6    Носки беговые Camino
# Name: Name, dtype: object

# %%
orders_products.groupby('ID Покупателя')['Price'].sum().sort_values(ascending=False)
# Out:
# ID Покупателя
# 7     17096.0
# 5     14042.0
# 8       697.0
# 1       448.0
# 9       344.0
# 10      199.0
# Name: Price, dtype: float64
