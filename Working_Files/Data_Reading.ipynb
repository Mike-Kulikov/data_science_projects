# %%
import pandas as pd

# %%
# data=pd.read_csv ('/home/mike/Documents/Coding/Data/ErrorEnCoding.csv', header=None )


from chardet.universaldetector import UniversalDetector # Импортируем субмодуль chardet.universaldetector

detector = UniversalDetector()
with open('/home/mike/Documents/Coding/Data/ErrorEnCoding.csv', 'rb') as fh:
    for line in fh:
        detector.feed(line)
        if detector.done:
            break
detector.close()
# Out:
# {'encoding': 'KOI8-R', 'confidence': 0.8402412806602051, 'language': 'Russian'}

# %%
data=pd.read_csv('/home/mike/Documents/Coding/Data/ErrorEnCoding.csv', encoding='koi8-r', header=None )
display(data)
# Out:
#             0                           1             2
# 0   User_943         Accumanst@gmail.com         Ижевск
# 1   User_908           Advismowr@mail.ru         Ижевск
# 2   User_962             Anachso@ukr.net      Краснодар
# 3   User_973            Antecia@inbox.ru          Пермь
# 4   User_902          Balliaryva@ukr.net
# ..        ...                         ...           ...
# 95  User_959    UpdatesCurious@yahoo.com         Тюмень
# 96  User_901          V2artierso@mail.ru    Арзангелтск
# 97  User_970            Vashoterlo@bk.ru        Воронеж
# 98  User_965         Visuareda@yahoo.com        Воронеж
# 99  User_921                Aavast@ya.ru         Ижевск
#
# [100 rows x 3 columns]

# %%
data = pd.read_table('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv', sep=',')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  object
#  2   Address        18396 non-null  object
#  3   Rooms          18396 non-null  int64
#  4   Type           18396 non-null  object
#  5   Price          18396 non-null  float64
#  6   Method         18396 non-null  object
#  7   SellerG        18396 non-null  object
#  8   Date           18396 non-null  object
#  9   Distance       18395 non-null  float64
#  10  Postcode       18395 non-null  float64
#  11  Bedroom2       14927 non-null  float64
#  12  Bathroom       14925 non-null  float64
#  13  Car            14820 non-null  float64
#  14  Landsize       13603 non-null  float64
#  15  BuildingArea   7762 non-null   float64
#  16  YearBuilt      8958 non-null   float64
#  17  CouncilArea    12233 non-null  object
#  18  Lattitude      15064 non-null  float64
#  19  Longtitude     15064 non-null  float64
#  20  Regionname     18395 non-null  object
#  21  Propertycount  18395 non-null  float64
# dtypes: float64(12), int64(2), object(8)
# memory usage: 3.1+ MB

# %%
data = pd.read_csv('/home/mike/Documents/Coding/Data/students_performance.zip')
display(data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
compression_opts = dict(method='zip', archive_name='out.csv')
data.to_csv('/home/mike/Documents/Coding/Data/out.zip', index=False, compression=compression_opts)

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 7.9 MB/s
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
ratings = pd.read_excel('/home/mike/Documents/Coding/Data/ratings+movies.xlsx', sheet_name='ratings')         
movies = pd.read_excel('/home/mike/Documents/Coding/Data/ratings+movies.xlsx', sheet_name='movies')         
joined = ratings.merge(movies, on='movieId', how='left')         
joined.to_excel('/home/mike/Documents/Coding/Data/joined.xlsx', sheet_name='JOINED', index=False)

# %%
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100836 entries, 0 to 100835
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
#  4   title      100836 non-null  object
#  5   genres     100836 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.4+ MB

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /home/mike/anaconda3/envs/sf/lib/python3.8/site-packages (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mike/anaconda3/envs/sf/lib/python3.8/site-packages (from requests) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/mike/anaconda3/envs/sf/lib/python3.8/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mike/anaconda3/envs/sf/lib/python3.8/site-packages (from requests) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mike/anaconda3/envs/sf/lib/python3.8/site-packages (from requests) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

print(response) # Выводим значение response на экран как объект
print(response.status_code) # Выводим числовое значение response на экран
# Out:
# <Response [200]>

# %%
print(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# {
#     "Date": "2021-12-04T11:30:00+03:00",
#     "PreviousDate": "2021-12-03T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2021\/12\/03\/daily_json.js",
#     "Timestamp": "2021-12-04T23:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 52.0991,
#             "Previous": 52.6593
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 43.4035,
#             "Previous": 43.5925
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 97.9449,
#             "Previous": 98.4158
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 15.0342,
#             "Previous": 15.216
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 29.004,
#             "Previous": 29.0857
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 42.5889,
#             "Previous": 42.8485
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 13.0594,
#             "Previous": 13.0032
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 22.7653,
#             "Previous": 23.1695
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 94.6534,
#             "Previous": 95.09
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 11.2028,
#             "Previous": 11.2687
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 73.7426,
#             "Previous": 74.0637
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 83.2406,
#             "Previous": 83.8105
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 98.2331,
#             "Previous": 98.8537
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 16.8113,
#             "Previous": 16.7926
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 57.535,
#             "Previous": 57.8758
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 86.9433,
#             "Previous": 87.3145
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 11.578,
#             "Previous": 11.6213
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 41.5451,
#             "Previous": 41.7143
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 81.0189,
#             "Previous": 81.6426
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 18.0689,
#             "Previous": 18.2207
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 16.832,
#             "Previous": 16.9288
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 103.2772,
#             "Previous": 103.6521
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 53.811,
#             "Previous": 54.2075
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 65.3167,
#             "Previous": 65.6012
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 53.5745,
#             "Previous": 54.9626
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 21.0995,
#             "Previous": 21.1913
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 68.5323,
#             "Previous": 68.7909
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 27.0331,
#             "Previous": 27.1119
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 32.7076,
#             "Previous": 32.9795
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 81.0189,
#             "Previous": 81.5949
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 80.0767,
#             "Previous": 80.3555
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 46.1312,
#             "Previous": 46.4999
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 62.4331,
#             "Previous": 63.063
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 64.9915,
#             "Previous": 65.3897
#         }
#     }
# }

# %%
from pprint import pprint # Импортируем функцию pprint()
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран)
# Out:
# {'Date': '2021-12-04T11:30:00+03:00',
#  'PreviousDate': '2021-12-03T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2021/12/03/daily_json.js',
#  'Timestamp': '2021-12-04T23:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 15.216,
#                     'Value': 15.0342},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 52.6593,
#                     'Value': 52.0991},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 43.5925,
#                     'Value': 43.4035},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 42.8485,
#                     'Value': 42.5889},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 13.0032,
#                     'Value': 13.0594},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 29.0857,
#                     'Value': 29.004},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 57.8758,
#                     'Value': 57.535},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 80.3555,
#                     'Value': 80.0767},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайский юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 11.6213,
#                     'Value': 11.578},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 32.9795,
#                     'Value': 32.7076},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 11.2687,
#                     'Value': 11.2028},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 83.8105,
#                     'Value': 83.2406},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 98.4158,
#                     'Value': 97.9449},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 95.09,
#                     'Value': 94.6534},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 23.1695,
#                     'Value': 22.7653},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 98.8537,
#                     'Value': 98.2331},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 65.3897,
#                     'Value': 64.9915},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 87.3145,
#                     'Value': 86.9433},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 63.063,
#                     'Value': 62.4331},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 16.7926,
#                     'Value': 16.8113},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 41.7143,
#                     'Value': 41.5451},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 81.6426,
#                     'Value': 81.0189},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 18.2207,
#                     'Value': 18.0689},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 16.9288,
#                     'Value': 16.832},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 81.5949,
#                     'Value': 81.0189},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 54.2075,
#                     'Value': 53.811},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 65.6012,
#                     'Value': 65.3167},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 21.1913,
#                     'Value': 21.0995},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 54.9626,
#                     'Value': 53.5745},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 27.1119,
#                     'Value': 27.0331},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 74.0637,
#                     'Value': 73.7426},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 68.7909,
#                     'Value': 68.5323},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 103.6521,
#                     'Value': 103.2772},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 46.4999,
#                     'Value': 46.1312}}}

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 83.8105,
#  'Value': 83.2406}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %%
import requests # Импортируем библиотеку requests
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!doctype html>
# <html class="no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#                 <meta name='wmail-verification' content='7991d7eb02d759f05b9050e111a7e3eb' />
#
#     <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021" />
#
#         <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#
#     	    <meta itemprop="datePublished" content="2021-10-11"/>
#
# 	    <meta name="mediator_author" content="Илья Ферапонтов"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#         <meta name="author" content="Илья Ферапонтов" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021" />
#         <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#         <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1638279331">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1635965090">
#
#             <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#         <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/195458/360.js"></script>
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://nplus1.ru/news/2021/10/11/econobel2021"},"headline":"Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей","description":"Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. ","image":"https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg","author":{"@type":"Person","name":"Илья Ферапонтов"},"publisher":{"@type":"Organization","name":"N + 1","logo":{"@type":"ImageObject","url":"https://nplus1.ru/i/logo-alt.png"}},"datePublished":"2021-10-11"}</script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" class="_inner  ">
#
# <div class="shadow-overlay"></div>
# <link property='' rel='stylesheet' href='//s.luxupcdnc.com/cp/all/cookies_policy.css' />
# <script type='text/javascript'>_cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};</script>
# <script async type='text/javascript' src='//s.luxupcdnc.com/cp/all/cookies_policy.js'></script>
#
#
#
#
#
#
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
#
#
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Растяжка_100%х250-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_162739969569252320"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#         containerId: 'adfox_162739969569252320',
#             params: {
#                 pp: 'g',
#             ps: 'fbio',
#             p2: 'hhkj'
#             }
#         })
#     })
# </script>
#
#
#
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/applying-statistics" class="">Характеристика статистики</a>
#                 </li>
#                             <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#                             <li>
#                     <a href="/theme/offline" class="">N + Offline</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="applying-statistics">
#             <a href="/theme/applying-statistics" class="">Характеристика статистики</a>
#         </li>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#                 <li data-name="offline">
#             <a href="/theme/offline" class="">N + Offline</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2021/12/01/physics-problems" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/12/01/physics-problems" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Игорь Иванов &laquo;Как ломаются спагетти и другие задачи по физике&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/11/30/into-the-abyss" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Энтони Дэвид &laquo;Глядя в бездну. Заметки нейропсихиатра о душевных расстройствах&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/11/26/a-woman-s-heart" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Анджела Маас &laquo;Женское сердце. Современный подход к здоровью женщин&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/11/25/deep-medicine" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Эрик Тополь &laquo;Искусственный интеллект в медицине&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/11/23/the-russian-job" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Дуглас Смит &laquo;Российская миссия. Забытая история о том, как Америка спасла Советский Союз от гибели&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/11/11/a-surgeons-notes-on-performance" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Атул Гаванде &laquo;Все возможное: Как врачи спасают наши жизни&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/11/02/rudalle" class="container-link">
#                     <div class="heading"><span>Мезонин</span></div>
#                     <div class="link"><span>Лучше синица в руках: о трудностях перевода</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/11/03/dune-climate" class="container-link">
#                     <div class="heading"><span>Эксперименты</span></div>
#                     <div class="link"><span>Дюна: мы сделали модель планеты Арракис, чтобы узнать, выживет ли там человек</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/11/03/tales-from-both-sides-of-the-brain" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Майкл Газзанига &laquo;Истории от разных полушарий мозга. Жизнь в нейронауке&raquo;</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2021/12/02/useful-delusions" class="container-link active">
#         	        	<div class="heading"><span>Книжная полка</span></div>
#             	    	<div class="link"><span>Шанкар Ведантам и Билл Меслер &laquo;Иллюзия правды. Почему наш мозг стремится обмануть себя и других?&raquo;</span></div>
# 		            </a>
#
#             <!-- here -->
#                     </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="30917" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="economics" href="/rubric/economics">Экономика</a>
#                                                 <a data-theme="nobelprize" href="/theme/nobelprize">Нобелевская премия</a>
#                     </p>
#         <p class="table">
#             <a href="/news/2021/10/11">
#                 <time itemprop="datePublished" content="2021-10-11" data-unix="1633946665">
#                     <span>13:04</span>
#                     <span>11 Окт. 2021</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/1.1">
#                 <span>Сложность</span>
#                 <span class="difficult-value">1.1</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Илья Ферапонтов';
#         _dlData.custom_difficult = '1.1';
#         _dlData.custom_rubric.push('Экономика');
#                 _dlData.custom_theme = 'Нобелевская премия';
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg"/>
#                                                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Премия Шведского национального банка по&nbsp;экономическим наукам памяти Альфреда Нобеля за&nbsp;2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a>&nbsp;на&nbsp;официальном сайте Нобелевской премии.</p>
#
# <div class="incut incut-gallery " data-id="30917">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.</p>
#
#                                             	    <p class="credits">Niklas Elmehed © Nobel Prize Outreach</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Премия по&nbsp;экономике, в&nbsp;отличие от&nbsp;Нобелевских премий по&nbsp;физиологии и&nbsp;медицине, физике, химии и&nbsp;литературе, а&nbsp;также премии мира, была учреждена не&nbsp;самим Альфредом Нобелем, а&nbsp;Банком Швеции в&nbsp;1968&nbsp;году. Ее&nbsp;размер равен размеру остальных премий.<p>Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p><p>Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p><p>Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на&nbsp;основе наукометрических данных, в&nbsp;2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в&nbsp;экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и&nbsp;Дэвиду Тису (David Teece) за&nbsp;исследование инноваций.</p>
#
# <p>Кроме того, в&nbsp;списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а&nbsp;также Кармен Рейнхарт (Carmen Reinhart) и&nbsp;Кеннет Рогофф (Kenneth Rogoff)&nbsp;— авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90&nbsp;процентов от&nbsp;ВВП, скорость роста ВВП падает вдвое.</p>
#
# <p>В&nbsp;2020 году премию по&nbsp;экономике присудили Полу Милгрому и&nbsp;Роберту Уилсону за&nbsp;развитие теории аукционов и&nbsp;изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и&nbsp;разрабатывали новые форматы проведения аукционов для продажи товаров и&nbsp;услуг, которые трудно продавать с&nbsp;помощью традиционных методов. Читайте об&nbsp;их&nbsp;работах в&nbsp;нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p>
#
# <p>В 2019 году премии памяти Нобеля по&nbsp;экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и&nbsp;Майкл Кремер&nbsp;— «за&nbsp;экспериментальный подход к&nbsp;искоренению глобальной бедности». Подробнее о&nbsp;заслугах лауреатов можно прочесть в&nbsp;нашем материале&nbsp;<a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на&nbsp;бедных»</a>. В&nbsp;2018 года награда была присуждена Уильяму Нордхаусу за&nbsp;«интеграцию изменения климата в&nbsp;долгосрочный макроэкономический анализ» и&nbsp;Полу Ромеру за&nbsp;«интеграцию технологических инноваций в&nbsp;долгосрочный макроэкономический анализ». Об&nbsp;их&nbsp;работах можно прочитать в&nbsp;материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p>
#
# <p><i>Сергей Кузнецов</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- go go go -->
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Mobile_footer_300x250-->
# <!--Расположение: низ страницы-->
# <div id="adfox_163818699372686647"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#             containerId: 'adfox_163818699372686647',
#             params: {
#                 pp: 'i',
#                 ps: 'fbio',
#                 p2: 'hjcg'
#             }
#         })
#     })
# </script>
#
#
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                                 <div class="ad">
#                                                                 	                            	<!-- go go go -->
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Боковой_300x600-->
# <!--Расположение: верх страницы-->
# <div id="adfox_163818703040233699"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#             containerId: 'adfox_163818703040233699',
#             params: {
#                 pp: 'g',
#                 ps: 'fbio',
#                 p2: 'hiyr'
#             }
#         })
#     })
# </script>
#
#
#
#                     	                                                                </div>
#
#
#                 <meter class="top"></meter>
#
#
#
#
#                     <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/12/04/symbols-of-rurikids" data-id="31569" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2021/12/04/bd38211d7f43dbaaa37a8f7a76e5e0e6.png"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2021-12-04">вчера</span>
#                         </div>
#                         <h3>Археологи нашли в Пскове артефакт из лосиного рога со знаками Рюриковичей</h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/12/04/ancient-ornaments" data-id="31561" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2021-12-04">вчера</span>
#                 </div>
#
#                                     <h3>Китайцев уличили в подделке палеолитических подвесок из зубов животных</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/12/04/v-1298-tau" data-id="31567" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2021-12-04">вчера</span>
#                 </div>
#
#                                     <h3>Молодые экзопланеты-гиганты не вписались в теоретические модели по скорости сжатия</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/12/04/kill-monkey-save-thrush" data-id="31568" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2021-12-04">вчера</span>
#                 </div>
#
#                                     <h3>Инвазивных мартышек уличили в разорении гнезд вымирающих дроздов</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/12/03/cannabis-odor-VSC" data-id="31564" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2021-12-03">03 декабря</span>
#                 </div>
#
#                                     <h3>Химики разобрались в неприятном запахе конопли</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                            <!-- go go go -->
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Нижний_баннер_960x400-->
# <!--Расположение: низ страницы-->
# <div id="adfox_163818697041091564"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#             containerId: 'adfox_163818697041091564',
#             params: {
#                 pp: 'i',
#                 ps: 'fbio',
#                 p2: 'hkts'
#             }
#         })
#     })
# </script>
#
#
#                                                             </div>
#
#
#             </div>
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/12/03/bronze-age-hoards" data-id="31554" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2021/12/03/b278afdba4d71ee5d888ac60af4d40b4.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Девочка-подросток нашла на английской ферме клад с боевыми топорами бронзового века</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/12/03/b62-12" data-id="31566" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2021/12/03/c555db9d62214bc29a3e3b6cc967eeb8.jpeg)" class="ill"></div>
#
#
#
#                                     <h3>Американцы собрали первую серийную модернизированную термоядерную бомбу</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/12/03/gj-367-b" data-id="31553" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2021/12/02/8892de337ae3c1bfca13b70936abacad.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Астрономы нашли субземлю с огромным железным ядром</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2021/12/03/de5f6e3fddf4c75b9215baeac5775fb0.jpg" style=background-image:url(https://nplus1.ru/images/2021/12/03/5ec207002ce0c913a000e018824b4254.jpg)>
#
#     <a href="/material/2021/12/03/russian-soil" data-id="31560" >
#         <div class="caption">
#                                                                                     <h3>Это наша земля</h3>
#                     <p class="subtitle">Какими бывают и как выглядят почвы России</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/ecology">Экология и климат</a>
#             </li>
#                                 </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="Zc3GZtwPpKkq60AvVRrUKqb7IAB3nXkAjCqOveOi">
#         <input type="hidden" name="id_news" value="30917">
#         <input type="hidden" name="id_author" value="120">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="Zc3GZtwPpKkq60AvVRrUKqb7IAB3nXkAjCqOveOi">
#         <input type="hidden" name="id_news" value="30917">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">8.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/11/30/skyrmion-light-beam">Физики впервые пронаблюдали трехмерный оптический скирмион в луче света</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/blog/2021/11/30/imagine">Вупи Голдберг в векторах: оцениваем размерность пространства лиц</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/12/02/surprise-fm">Скрученный двойной бислой трииодида хрома удивил физиков ферромагнетизмом</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2021/12/01/tarim-people">Культура фаллосов и вульв</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/11/30/kondo-moire">Муаровая сверхрешетка помогла настроить спин атома железа</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/12/03/quantum-OPM-MEG">Магнитометры улучшили качество и скорость нейровизуализации</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/12/02/atomic-compass">Векторный свет превратил атомный газ в компас</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2021/12/01/nipkow-avito">Механическое что-то-такое-видение</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/11/29/cortex-alternative-splicing">Профиль РНК поможет понять причины заболеваний головного мозга</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/11/29/new-method-anyons">Физики предложили искать энионы по создаваемому ими тепловому току</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="https://nplus.pro" target="_blank">N + Production</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2021 <i>N&nbsp;+&nbsp;1</i> Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N&nbsp;+&nbsp;1</i>.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                         <script async type="text/javascript" src="//s.luxupcdnc.com/t/consent_195458.js"></script>
#                         <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#                     </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://www.facebook.com/nplusone"><i class="fa fa-facebook"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
#
#
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1633360304"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.8 MB/s
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.10.0 soupsieve-2.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup

# %%
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
print(page.find('h1').text) # Применяем метод find() к объекту и выводим результат на экран
# Out:
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
print(page.find('time').text) # Выводим на экран содержимое атрибута text тега time
# Out:
# 13:04
# 11 Окт. 2021

# %%
print(page.find('div', class_='body').text) # Выводим содержимое атрибута text тега div класса body js-mediator-article
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.
#
#
#
#
#
#
#
#
#
# Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.
# Niklas Elmehed © Nobel Prize Outreach
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году предположила, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.
# Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.
# В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале «Тонкости молотка».
# В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале «Опыты на бедных». В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале «Почем знания для природы».
# Сергей Кузнецов

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 929

# %%
import requests # Импортируем модуль requests
token = '4423195e4423195e4423195e4e4459446f444234423195e258ed3d1df5132eed5d3ae72' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"first_name":"Павел","id":1,"last_name":"Дуров","can_access_closed":true,"is_closed":false,"sex":2,"bdate":"10.10.1984"}]}

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
print(user['first_name'])
# Out:
# 10.10.1984
# Павел

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %%
import requests
#token = '4423195e4423195e4423195e4e4459446f444234423195e258ed3d1df5132eed5d3ae72'
url = 'https://api.vk.com/method/users.get'
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params).json()['response']
men=0
women=0
for elem in response:
    if elem['sex'] == 2:
        men+=1
    elif elem['sex'] == 1:
        women+=1
    else:
        continue
print(round(women/(men+women),2))
# Out:
# 0.48

# %%
import requests # Импортируем модуль requests
token = '4423195e4423195e4423195e4e4459446f444234423195e258ed3d1df5132eed5d3ae72' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 12099432, 'items': [5, 6, 19, 34, 47, 54, 79, 177, 193, 198, 212, 219, 239, 243, 254, 345, 404, 406, 407, 467, 485, 510, 550, 619, 628, 640, 643, 690, 702, 720, 721, 724, 744, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1290, 1301, 1333, 1334, 1336, 1351, 1359, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1531, 1543, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1868, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2145, 2150, 2195, 2201, 2202, 2230, 2236, 2273, 2281, 2294, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2515, 2527, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3140, 3172, 3186, 3203, 3213, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3597, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3713, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4189, 4192, 4236, 4262, 4282, 4326, 4360, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4625, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4754, 4767, 4769, 4818, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 4985, 5011, 5017, 5024, 5067, 5073, 5161, 5166, 5183, 5262, 5273, 5280, 5286, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5479, 5481, 5527, 5546, 5547, 5585, 5590, 5606, 5615, 5629, 5634, 5665, 5690, 5701, 5733, 5768, 5775, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5990, 5991, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6950, 6960, 6994, 7012, 7036, 7040, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7652, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7833, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8066, 8080, 8093, 8149, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8240, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8910, 8937, 8959, 8972, 9000, 9014, 9016, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9319, 9355, 9399, 9412, 9435, 9444, 9447, 9450, 9459, 9466, 9469, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9981, 9993, 10090, 10117, 10155, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11059, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11446, 11451, 11483, 11568, 11649, 11727, 11747, 11754, 11763, 11768, 11782, 11792, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12625, 12707, 12716, 12718, 12736, 12748, 12762, 12797, 128 ...

# %%
import requests # Импортируем модуль requests
token = '4423195e4423195e4423195e4e4459446f444234423195e258ed3d1df5132eed5d3ae72' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [5, 6, 19, 34, 47, 54, 79, 177, 193, 198, 212, 219, 239, 243, 254, 345, 404, 406, 407, 467]

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = '4423195e4423195e4423195e4e4459446f444234423195e258ed3d1df5132eed5d3ae72' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000
offset = 0
user_ids = []
while offset < 5000:
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token}
    response = requests.get(url, params = params)
    data = response.json()
    user_ids += data['response']['items']
    offset += count
    print('Ожидаю 0.5 секунды...')
    time.sleep(0.5)
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = '4423195e4423195e4423195e4e4459446f444234423195e258ed3d1df5132eed5d3ae72' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 448,
#               'items': [{'attachments': [{'type': 'video',
#                                           'video': {'access_key': '109c7876043aa21574',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 95,
#                                                     'date': 1634027241,
#                                                     'description': 'ВКонтакте '
#                                                                    'становится '
#                                                                    'больше: '
#                                                                    'сервисы, '
#                                                                    'платежи, '
#                                                                    'VK Combo',
#                                                     'duration': 12,
#                                                     'first_frame_1280': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=1280x721&quality=96&sign=9591cd4916a1c6030587ea6ee35ca36f&c_uniq_tag=_6JHgNvxXpiQ7WpZfV20j92L0p0FOcj067JX3CJeP_k&type=video_first_frame',
#                                                     'first_frame_130': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=130x73&quality=96&sign=ba285b2f49ecf686ff094ce6ec76466d&c_uniq_tag=4Dpb8Hm_KOfhmq_YU0CHx7_BGC0gz1RE0VRhNV8PTdk&type=video_first_frame',
#                                                     'first_frame_160': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=160x90&quality=96&sign=4bb20311ea8c2960b3da70099bdcd124&c_uniq_tag=GipWZQ1lNMVF0nOdI9A4ptOZcixJkO5KvN1a5Rqtu4k&type=video_first_frame',
#                                                     'first_frame_320': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=320x180&quality=96&sign=bb5b01b40fb8d15b221b81237f5882bd&c_uniq_tag=u_4BfFJbk14xMh5gJ7-3ec7Bw175QobEUPP1_eu_fDc&type=video_first_frame',
#                                                     'first_frame_800': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=800x451&quality=96&sign=a42245e43d3cf6a743c6362dfff23b80&c_uniq_tag=7KxmmTNSMLxsuvOf9l8is8GvfJKdihbT1tjvsOugTY8&type=video_first_frame',
#                                                     'height': 720,
#                                                     'id': 456241031,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=1280x721&quality=96&sign=6d2576bae409edd8ff7cceeaccc46521&c_uniq_tag=9AUIYv2xBO60mNqUB7F22KZSIH1XrYt97d-tarH0oyE&type=video_thumb',
#                                                     'photo_130': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=f7af05c9a0bfa1185cfadf305839c49d&c_uniq_tag=jCM4yy-QXXdeznT1IAqp5zi5Qh-NxWZ_mx3g06GqZHw&type=video_thumb',
#                                                     'photo_320': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=aa25827598b22ed7ef9ab6b623df693b&c_uniq_tag=tqn_KwVTRRPl4ACiJSZ1aCmnq16MD1i6KYj5c3Kpg6c&type=video_thumb',
#                                                     'photo_800': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=a1fbd7b4e60567b6f42fee1c341fb176&c_uniq_tag=CEDSCNvFadVoa5ZclM4FLEqkYmher8ekCmcS5PPpp80&type=video_thumb',
#                                                     'repeat': 1,
#                                                     'title': 'Экосистема VK – '
#                                                              'встречайте!',
#                                                     'track_code': 'video_b9b221b5SOJpcN6-FFRMH0cxyuyG1fpP6gmbjntsOe0e49YXIKd4w3dy2dkXVE0WQFrP2bDnzn7aOqqKDA1VgR4',
#                                                     'views': 82338625,
#                                                     'width': 1278}}],
#                          'comments': {'can_post': 1,
#                                       'count': 6628,
#                                       'groups_can_post': True},
#                          'date': 1634026934,
#                          'edited': 1634031226,
#                          'from_id': -22822305,
#                          'hash': 'rnZ3XxEv_Sz20Kz1CQ',
#                          'id': 1229241,
#                          'is_pinned': 1,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 63543,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 11112, 'user_reposted': 0},
#                          'text': 'ВКонтакте становится больше\n'
#                                  '\n'
#                                  'Теперь бренд VK объединяет ещё больше '
#                                  'сервисов: [club39554210|Почту], '
#                                  '[club137839839|Юлу], [club17700656|Delivery '
#                                  'Club], [club66669811|Skillbox], '
#                                  '[club90274300|Ситимобил], '
#                                  '[club182144558|Самокат] и другие. Проекты '
#                                  'будут обмениваться самыми удачными решениями '
#                                  '— а значит, вы сможете ещё раньше пробовать '
type=video_thumb',
#                                                     'repeat': 1,
#                                                     'title': 'VK Mузыка. '
#                                                              'Слушайте друг '
#                                                              'друга',
#                                                     'track_code': 'video_02b8cbb1SZlsF7yWtOI07K6WJ_473KtgK5NFEE3vR5ZgOf-iXdNzv3MVuJTT5zPupJ5I_w7qmVQZpHcnSZgm-gw5',
#                                                     'views': 614139,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 388,
#                                       'groups_can_post': True},
#                          'date': 1638261939,
#                          'from_id': -22822305,
#                          'hash': 'qVvqpAP9zwM2Hvg3EA',
#                          'id': 1248805,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 667,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 135, 'user_reposted': 0},
#                          'text': 'Теперь только [club147845620|VK Музыка]. Мы '
#                                  'объединяем этим брендом музыку ВКонтакте и '
#                                  'наши новые продукты для артистов и лейблов. '
#                                  'Коллекции треков с этих платформ можно '
#                                  'слушать в отдельном приложении (в прошлом '
#                                  'BOOM): vk.cc/music\n'
#                                  '\n'
#                                  'На музыкальной витрине ВКонтакте всё '
#                                  'по-новому. В блоке «Собрано людьми» '
#                                  'плейлисты пользователей и сообществ, с '
#                                  'которыми совпадают вкусы, «Собрано '
#                                  'алгоритмами» — рекомендации на основе ваших '
#                                  'предпочтений, «Собрано редакцией» — '
#                                  'плейлисты разных жанров от музыкальной '
#                                  'редакции. Их показываем тоже с учётом ваших '
#                                  'интересов. А за свежими релизами всегда '
#                                  'можно заглянуть в «Обзор». \n'
#                                  '\n'
#                                  'Запускайте музыку там, где удобно: она '
#                                  'по-прежнему доступна и в привычном '
#                                  'приложении ВКонтакте, и в браузере. А с '
#                                  'подпиской — без рекламы, в фоновом режиме и '
#                                  'офлайн.',
#                          'views': {'count': 284053}},
#                         {'attachments': [{'photo': {'access_key': 'f72d8805e35a93853e',
#                                                     'album_id': -7,
#                                                     'date': 1638196150,
#                                                     'id': 457326029,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1248512,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=130x130&quality=96&sign=35883f71f7bd51351e548c8dd2efb9e2&c_uniq_tag=PmxP6qVuHLoyMhzsvZSdMRp4DX0ZItIcq_16gvwi22o&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=130x130&quality=96&sign=35883f71f7bd51351e548c8dd2efb9e2&c_uniq_tag=PmxP6qVuHLoyMhzsvZSdMRp4DX0ZItIcq_16gvwi22o&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=200x200&quality=96&sign=1ef7eb626e7a1ea0d79dfea7a7dda7f9&c_uniq_tag=DbT6BjmV7qd9Z9HhWyp_xb6O9Qg5-fW2V6SF3TvbZ1g&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=320x320&quality=96&sign=c7a9d4517669f21f96a9f20e924678c6&c_uniq_tag=in6mjdvoy2LcjCyJ7DlIt8d3KgUOSUSm6HWZhnFh1pg&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=510x510&quality=96&sign=e24826336f1077d60df85b3b9b8a1b18&c_uniq_tag=KSsvfDO4GO-igU36OyK8OG0NUDt1a3fAB53TrBzSWkw&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=75x75&quality=96&sign=0490996ee70e9ee4ee5fd8193d6c5678&c_uniq_tag=_NEQJN1BXgkbGO8L1SeWFTTXnNUeKMDvBz4YODPkB0I&type=album',
#                                                                'width': 75},
#                                                               {'height': 2160,
#                                                                'type': 'w',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=2160x2160&quality=96&sign=778d5acf5f11bf1ee2ada8d491c1025c&c_uniq_tag=sNpxXsVHr3Hripr0r60Se9zD5-wFJvBSYbs-IpbMrBg&type=album',
#                                                                'width': 2160},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=604x604&quality=96&sign=880c1eb466e4daaf342ae5444c52c1fb&c_uniq_tag=-UXSBF5R0yCzR46kW8mbniKXNPoT4f4FzbV_tAgzl1g&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=807x807&quality=96&sign=6b334d9620cdc321f19cda50f0bbf341&c_uniq_tag=eOwhnhD7fh105mIkf_nx9l4tfOKfk7OVq_HlHY7GgXg&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-22.userapi.com/impg/voMGEeyRF3lLWB6a07-9H83UwroX9U5KCGhSRQ/iD2vJ_nX7FQ.jpg?size=1280x1280&quality=96&sign=2d4bb6f4911c168ed3020d67da151e10&c_uniq_tag=ckUWBLX2mCybz9sM82Zj4jrsSlj7SWjDjohSmwmK7YE&type=album',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 210,
#                                       'groups_can_post': True},
#                          'date': 1638196201,
#                          'from_id': -22822305,
#                          'hash': 'i3gWmrVZXtX6Uh6fmA',
#                          'id': 1248512,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 666,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 141, 'user_reposted': 0},
#                          'text': 'Сколько человек поместится в онлайн-звонок? '
#                                  'А сколько из них смогут участвовать с видео? '
#                                  'В VK Звонках — сколько угодно! Всё '
#                                  'необходимое есть в новом разделе «Звонки». \n'
#                                  '\n'
#                                  'Свободно планируйте мощные '
#                                  'онлайн-мероприятия для подписчиков и уютные '
#                                  'посиделки с близкими, обсуждайте проекты с '
#                                  'коллегами на рабочих совещаниях, проводите '
#                                  'лекции и тренировки или присоединяйтесь к '
#                                  'ним. Можно мгновенно создать звонок по '
#                                  'ссылке (личный или от имени сообщества), а '
#                                  'также позвонить друзьям из списка контактов. '
#                                  'Следить за всеми звонками и не упустить '
#                                  'важные поможет история и вкладки с '
#                                  'пропущенными, завершёнными и текущими '
#                                  'вызовами.\n'
#                                  '\n'
#                                  'К звонку смогут присоединиться сколько '
#                                  'угодно участников и одновременно включить '
#                                  'свои видеокамеры. То есть полноценно '
#                                  'общаться в конференции, а не только смотреть '
#                                  'и слушать — мы первыми в мире избавились от '
#                                  'этого ограничения. Проводить онлайн-встречи '
#                                  'помогут инструменты платформы VK Звонки: зал '
#                                  'ожидания, управление микрофонами и камерами, '
#                                  'демонстрация экрана в 4К, интеллектуальное '
#                                  'шумоподавление. \n'
#                                  '\n'
#                                  'В версии для компьютера раздел «Звонки» '
#                                  'появился в меню слева, а в мобильном '
#                                  'приложении — в «Сервисах». Подробнее о том, '
#                                  'какие ещё функции есть в VK Звонках, читайте '
#                                  'в блоге: vk.com/blog/vk-calls-no-limit',
#                          'views': {'count': 395538}},
#                         {'attachments': [{'photo': {'access_key': 'b2972888cd5a3ef73b',
#                                                     'album_id': -7,
#                                                     'date': 1637941192,
#                                                     'id': 457325996,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1248068,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=130x130&quality=96&sign=80f51c45ba5b1b04177710c5d5adc90c&c_uniq_tag=_5-DEFPPMaphDKOgjKFK6oyVA_w4659oWHkHPju37YU&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=130x130&quality=96&sign=80f51c45ba5b1b04177710c5d5adc90c&c_uniq_tag=_5-DEFPPMaphDKOgjKFK6oyVA_w4659oWHkHPju37YU&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=200x200&quality=96&sign=799776ba95ec379df44cc715b7ac754c&c_uniq_tag=n8L62vCHrSm7kJAo9NZ81m_-Rqtzn5X7zCZ0RTCmRz8&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=320x320&quality=96&sign=56bd99bc71134103ddc9d0958364d0da&c_uniq_tag=tl1LVMYBsglBaOx5X3wkH0QeyFRao7CTtHk_ppVp6hw&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=510x510&quality=96&sign=1184a974ca98ba967a1d6cca367df1e1&c_uniq_tag=C5zg6Y7lOeferGx347ZtCy1e7CyEMzGUg67BV5oA7_E&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=75x75&quality=96&sign=4fc7f85452effb6c06896df6f4ba3af1&c_uniq_tag=6nhW7-5JLrj0voAzrW6Kz77XpiNLmK4ABU_h-wQdzpo&type=album',
#                                                                'width': 75},
#                                                               {'height': 1600,
#                                                                'type': 'w',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=1600x1600&quality=96&sign=264e1eff6f1f2eb63808d6ddb6167ccb&c_uniq_tag=1Fy3Q_HgtAynB3mScJYmXpKxIa6sw9taAABTqfr3FIo&type=album',
#                                                                'width': 1600},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=604x604&quality=96&sign=3e66d066457c6afdf54ffa98ebe0f6ba&c_uniq_tag=zPXUjAlso8nsdEFcjYv37wV5Br0nR4CrA4GarInJBg0&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=807x807&quality=96&sign=0b759798cd4cdf1eef4c7b93ff5e79a5&c_uniq_tag=Sgg3Bb-ifIFBDXrnHhjt8oqo5OwxIkMADBlvD51aetY&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-22.userapi.com/impg/UA3zbxNykUSuFVifFM-W3tJNguohEjvEYwPqPQ/OVBury0vV2A.jpg?size=1280x1280&quality=96&sign=46068edd14432670133b02dc46096ca2&c_uniq_tag=RQ9tTb6VYthhTiOFEWUVC2CQloIoeewFEbqzCRiSOCg&type=album',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 190,
#                                       'groups_can_post': True},
#                          'date': 1637941192,
#                          'from_id': -22822305,
#                          'hash': 'T8DI8rx_2fiXOoM0ow',
#                          'id': 1248068,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 728,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 94, 'user_reposted': 0},
#                          'text': 'Эксклюзивное шоу, мультфильмы для непосед '
#                                  'или новый сериал? Собирайте плейлист на '
#                                  'выходные уже сегодня: всё, что вы хотите '
#                                  'посмотреть, легко найдётся на новой '
#                                  '[https://vk.com/video|видеовитрине VK '
#                                  'Видео]! \n'
#                                  '\n'
#                                  'Заходите в «Видео» в версии ВКонтакте для '
#                                  'компьютера или на вкладке «Сервисы» в '
#                                  'мобильном приложении. И ныряйте в огромную '
#                                  'библиотеку: фильмы, сериалы, телешоу, матчи, '
#                                  'киберспортивные трансляции и ещё миллионы '
#                                  'роликов других жанров — выбирайте любой в '
#                                  'удобном рубрикаторе. Всё бесплатно и в '
#                                  'высоком качестве, вплоть до Full HD и 4К. \n'
#                                  '\n'
#                                  'Ещё больше контента со всей платформы — в '
#                                  'разделе «Для вас». Здесь умная система '
#                                  'рекомендаций собирает ролики, которые могут '
#                                  'вам понравиться: от сообществ, экспертов и '
#                                  'звёзд по вашим интересам. А во вкладке «Мои '
#                                  'видео» вы составляете свою коллекцию: из '
#                                  'загруженных, добавленных и понравившихся '
#                                  'роликов. Здесь также сохраняются записи '
#                                  'ваших трансляций и история просмотров — '
#                                  'чтобы легко вернуться к вебинару, который '
#                                  'смотрели недавно, или клипу, которым вдруг '
#                                  'захотелось поделиться. Ещё можно создавать '
#                                  'плейлисты: для себя или друзей и '
#                                  'подписчиков. Например, показать свои съёмки '

#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 11758,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 7895, 'user_reposted': 0},
#                          'text': 'Приложение теперь подстраивается под вас: '
#                                  'встречайте новую версию 7.0, в которой '
#                                  'навигация получила персонализацию. \n'
#                                  '\n'
#                                  'Магия начинается уже в нижнем меню. Оно '
# ...
#                                                    'description': 'Это '
#                                                                   'официальная '
#                                                                   'страница '
#                                                                   'команды '
#                                                                   'ВКонтакте. '
#                                                                   'Здесь Вы '
#                                                                   'можете '
#                                                                   'узнать обо '
#                                                                   'всех '
#                                                                   'изменениях '
#                                                                   'на сайте из '
#                                                                   'первых рук.',
#                                                    'photo': {'album_id': -2,
#                                                              'date': 1539167968,
#                                                              'id': 456250787,
#                                                              'owner_id': 100,
#                                                              'sizes': [{'height': 89,
#                                                                         'type': 'a',
#                                                                         'url': 'https://sun9-44.userapi.com/c851024/v851024915/1dac1/6N9_OSax3MY.jpg',
#                                                                         'width': 200},
#                                                                        {'height': 178,
#                                                                         'type': 'b',
#                                                                         'url': 'https://sun9-37.userapi.com/c851024/v851024915/1dabf/uFHPT3SaEHg.jpg',
#                                                                         'width': 400},
#                                                                        {'height': 200,
#                                                                         'type': 'c',
#                                                                         'url': 'https://sun9-9.userapi.com/c851024/v851024915/1dac3/m8iloMG93F4.jpg',
#                                                                         'width': 200},
#                                                                        {'height': 100,
#                                                                         'type': 'd',
#                                                                         'url': 'https://sun9-88.userapi.com/c851024/v851024915/1dac4/vwylArdnORY.jpg',
#                                                                         'width': 100},
#                                                                        {'height': 50,
#                                                                         'type': 'e',
#                                                                         'url': 'https://sun9-17.userapi.com/c851024/v851024915/1dac5/1zZW8OpvJrI.jpg',
#                                                                         'width': 50},
#                                                                        {'height': 479,
#                                                                         'type': 'k',
#                                                                         'url': 'https://sun9-74.userapi.com/c851024/v851024915/1dac0/gtTw5TRWm3g.jpg',
#                                                                         'width': 1074},
#                                                                        {'height': 240,
#                                                                         'type': 'l',
#                                                                         'url': 'https://sun9-61.userapi.com/c851024/v851024915/1dac2/qB4SVIFSN_o.jpg',
#                                                                         'width': 537},
#                                                                        {'height': 479,
#                                                                         'type': 'o',
#                                                                         'url': 'https://sun9-1.userapi.com/c851024/v851024915/1dabe/R1K3CB7ImZE.jpg',
#                                                                         'width': 1074}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Теория '
#                                                             'рукопожатий',
#                                                    'url': 'https://vk.com/app6711649_-22822305'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 1952,
#                                       'groups_can_post': True},
#                          'date': 1539171090,
#                          'from_id': -22822305,
#                          'hash': 'tCPKG_sI2dKCjJYw5A',
#                          'id': 524158,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 13312,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 535, 'user_reposted': 0},
#                          'text': 'Отмечайте день рождения ВКонтакте вместе с '
#                                  'нами. Мы подготовили несколько приложений, '
#                                  'чтобы отлично повеселиться. \n'
#                                  '\n'
#                                  'ВКонтакте можно общаться не только с '
#                                  'друзьями, но и со звёздами. Вы наверняка уже '
#                                  'знакомы со своим кумиром — через общих '
#                                  'друзей. Юрий Дудь, Данила Поперечный, Хабиб '
#                                  'Нурмагомедов, Монеточка, Филипп Киркоров и '

#                                                                'type': 'z',
#                                                                'url': 'https://sun6-21.userapi.com/impf/WhBoouw3NT2XvdJZTCcRFh04Rcc5pFL4_NOuQQ/ILk0D9j6qJ4.jpg?size=1280x768&quality=96&sign=d577d2654166ce7dbcb7c448c02963e4&c_uniq_tag=B4zD-qt7L6LbrtRGfcKZtKJJAa1U0pxiDZbs1wcKDDw&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 2820,
#                                       'groups_can_post': True},
#                          'date': 1539153523,
#                          'from_id': -22822305,
#                          'hash': '1GXhc_2BO095_F6TzA',
#                          'id': 522858,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 29716,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 827, 'user_reposted': 0},
#                          'text': 'Сегодня мы празднуем день рождения — '
#                                  'ВКонтакте 12 лет. За это время мы запустили '
#                                  'десятки сервисов и собрали вместе почти 100 '
#                                  'миллионов человек: vk.cc/VK12\n'
#                                  '\u200b\u200b\n'
#                                  '\u200b\u200bНаша гордость — это '
#                                  'пользователи, у которых горят глаза от новых '
#                                  'идей и желания сделать мир лучше. Наша '
#                                  'гордость — это Вы. Пусть стремление к '
#                                  'высоким идеалам всегда остаётся в Вашем '
#                                  'сердце, а ВКонтакте и дальше помогает '
#                                  'поддерживать связь с важными для Вас людьми, '
#                                  'открывать мир и реализовывать мечты. \n'
#                                  '\u200b\u200b\n'
#                                  '\u200b\u200bРазделите торжество с друзьями. '
#                                  'Сегодня Вы можете отправить 12 бесплатных '
#                                  'подарков с праздничным Персиком — одним из '
#                                  'символов ВКонтакте. \n'
#                                  '\u200b\u200b\n'
#                                  '\u200b\u200bС днём рождения!\n'
#                                  '\u200b\u200b#VK12',
#                          'views': {'count': 4514335}}]}}

# %%
response.json()['response']['items'][0]
# Out:
# {'id': 1229241,
#  'from_id': -22822305,
#  'owner_id': -22822305,
#  'date': 1634026934,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'ВКонтакте становится больше\n\nТеперь бренд VK объединяет ещё больше сервисов: [club39554210|Почту], [club137839839|Юлу], [club17700656|Delivery Club], [club66669811|Skillbox], [club90274300|Ситимобил], [club182144558|Самокат] и другие. Проекты будут обмениваться самыми удачными решениями — а значит, вы сможете ещё раньше пробовать новые возможности.\n\nПрочитайте больше об [https://vk.com/ecosystem|экосистеме VK] 👈 По ссылке — подарок: подписка VK Combo за 75 рублей в месяц. Правила акции: vk.cc/c6Rsim',
#  'is_pinned': 1,
#  'attachments': [{'type': 'video',
#    'video': {'access_key': '109c7876043aa21574',
#     'can_comment': 0,
#     'can_like': 1,
#     'can_repost': 1,
#     'can_subscribe': 1,
#     'can_add_to_faves': 1,
#     'can_add': 1,
#     'comments': 95,
#     'date': 1634027241,
#     'description': 'ВКонтакте становится больше: сервисы, платежи, VK Combo',
#     'duration': 12,
#     'photo_130': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=130x96&quality=96&keep_aspect_ratio=1&background=000000&sign=f7af05c9a0bfa1185cfadf305839c49d&c_uniq_tag=jCM4yy-QXXdeznT1IAqp5zi5Qh-NxWZ_mx3g06GqZHw&type=video_thumb',
#     'photo_320': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=320x240&quality=96&keep_aspect_ratio=1&background=000000&sign=aa25827598b22ed7ef9ab6b623df693b&c_uniq_tag=tqn_KwVTRRPl4ACiJSZ1aCmnq16MD1i6KYj5c3Kpg6c&type=video_thumb',
#     'photo_800': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=800x450&quality=96&keep_aspect_ratio=1&background=000000&sign=a1fbd7b4e60567b6f42fee1c341fb176&c_uniq_tag=CEDSCNvFadVoa5ZclM4FLEqkYmher8ekCmcS5PPpp80&type=video_thumb',
#     'photo_1280': 'https://sun6-23.userapi.com/impf/WmFqWlTb94_gIZLJXRrk9q6iFOMqHzWdXV3Eug/cWXmcW9Ns-w.jpg?size=1280x721&quality=96&sign=6d2576bae409edd8ff7cceeaccc46521&c_uniq_tag=9AUIYv2xBO60mNqUB7F22KZSIH1XrYt97d-tarH0oyE&type=video_thumb',
#     'first_frame_130': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=130x73&quality=96&sign=ba285b2f49ecf686ff094ce6ec76466d&c_uniq_tag=4Dpb8Hm_KOfhmq_YU0CHx7_BGC0gz1RE0VRhNV8PTdk&type=video_first_frame',
#     'first_frame_160': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=160x90&quality=96&sign=4bb20311ea8c2960b3da70099bdcd124&c_uniq_tag=GipWZQ1lNMVF0nOdI9A4ptOZcixJkO5KvN1a5Rqtu4k&type=video_first_frame',
#     'first_frame_320': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=320x180&quality=96&sign=bb5b01b40fb8d15b221b81237f5882bd&c_uniq_tag=u_4BfFJbk14xMh5gJ7-3ec7Bw175QobEUPP1_eu_fDc&type=video_first_frame',
#     'first_frame_800': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=800x451&quality=96&sign=a42245e43d3cf6a743c6362dfff23b80&c_uniq_tag=7KxmmTNSMLxsuvOf9l8is8GvfJKdihbT1tjvsOugTY8&type=video_first_frame',
#     'first_frame_1280': 'https://sun6-21.userapi.com/impf/Hhu5CvS-j8201kC34RtfBGMJLUnuhYWpjZEg2Q/9xuIurrlyRI.jpg?size=1280x721&quality=96&sign=9591cd4916a1c6030587ea6ee35ca36f&c_uniq_tag=_6JHgNvxXpiQ7WpZfV20j92L0p0FOcj067JX3CJeP_k&type=video_first_frame',
#     'width': 1278,
#     'height': 720,
#     'id': 456241031,
#     'owner_id': -22822305,
#     'title': 'Экосистема VK – встречайте!',
#     'track_code': 'video_b9b221b5SOJpcN6-FFRMH0cxyuyG1fpP6gmbjntsOe0e49YXIKd4w3dy2dkXVE0WQFrP2bDnzn7aOqqKDA1VgR4',
#     'repeat': 1,
#     'views': 82338625}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'can_post': 1, 'count': 6628, 'groups_can_post': True},
#  'likes': {'can_like': 1, 'count': 63543, 'user_likes': 0, 'can_publish': 1},
#  'reposts': {'count': 11112, 'user_reposted': 0},
#  'views': {'count': 92794366},
#  'edited': 1634031226,
#  'hash': 'rnZ3XxEv_Sz20Kz1CQ'}

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'ВКонтакте становится больше\n\nТ': [6628, 63543, 11112, 1634026934],
#  'Встречайте VK Видео — крупнейш': [655, 1724, 672, 1634311497],
#  'За столом на нашей «Вечеринке»': [1437, 2212, 532, 1634482803],
#  'Как и обещали, в наш день рожд': [4308, 4384, 1059, 1633878003],
#  'Какой праздник без игр и весел': [4209, 22239, 7600, 1633724266],
#  'Приложение теперь подстраивает': [2395, 11758, 7895, 1635347061],
#  'Сколько человек поместится в о': [210, 666, 141, 1638196201],
#  'Теперь смотреть ролики из библ': [158, 586, 116, 1638544577],
#  'Теперь только [club147845620|V': [388, 667, 135, 1638261939],
#  'Эксклюзивное шоу, мультфильмы ': [190, 728, 94, 1637941192]}

# %%
pip install schedule
# Out:
# Collecting schedule
#   Downloading schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import schedule # Импортируем модуль schedule
import time

# %%
def task(): 
    print('Hello! I am a task!') 
    return

# %%
def task(): 
    print('Hello! I am a task!') 
    return 


schedule.every(15).seconds.do(task)

while True: 
    schedule.run_pending() 
    time.sleep(1)
# Out:
# Hello! I am a task!
# Hello! I am a task!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7815/1234019426.py in <module>
#       4 while True:
#       5     schedule.run_pending()
# ----> 6     time.sleep(1)
#
# KeyboardInterrupt:
